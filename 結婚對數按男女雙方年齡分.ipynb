# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 分析107年結婚對數按男女雙方年齡分

# %%
df = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=102822&md5_url=ba570b3564663eebbc9480a3c282213c')
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   statistic_yyy according site_id female_age male_age marry_pair
# 0          統計年度       按照別     區域別       女方年齡     男方年齡       結婚對數
# 1           107    按發生日期分  新北市板橋區      未滿15歲    未滿15歲          0
# 2           107    按發生日期分  新北市板橋區      未滿15歲      15歲          0
# 3           107    按發生日期分  新北市板橋區      未滿15歲      16歲          0
# 4           107    按發生日期分  新北市板橋區      未滿15歲      17歲          0

# %% [markdown]
# ### 刪去不必要的欄位

# %%
df.drop("according",axis=1,inplace=True)

# %%
df.head()
# Out:
#   statistic_yyy site_id female_age male_age marry_pair
# 0          統計年度     區域別       女方年齡     男方年齡       結婚對數
# 1           107  新北市板橋區      未滿15歲    未滿15歲          0
# 2           107  新北市板橋區      未滿15歲      15歲          0
# 3           107  新北市板橋區      未滿15歲      16歲          0
# 4           107  新北市板橋區      未滿15歲      17歲          0

# %% [markdown]
# ## 找出男方、女方年齡１８歲　結婚對數為１

# %%
df[(df.female_age=='18歲')&(df.male_age=='18歲')&(df.marry_pair == '1')]
# Out:
#        statistic_yyy site_id female_age male_age marry_pair
# 2813             107  新北市新莊區        18歲      18歲          1
# 4841             107  新北市鶯歌區        18歲      18歲          1
# 5517             107  新北市三峽區        18歲      18歲          1
# 9573             107  新北市五股區        18歲      18歲          1
# 20389            107  臺北市信義區        18歲      18歲          1
# 32557            107  桃園市八德區        18歲      18歲          1
# 33909            107  桃園市平鎮區        18歲      18歲          1
# 34585            107  桃園市新屋區        18歲      18歲          1
# 39317            107  臺中市北　區        18歲      18歲          1
# 48105            107  臺中市大雅區        18歲      18歲          1
# 67709            107  臺南市新化區        18歲      18歲          1
# 77173            107  臺南市東　區        18歲      18歲          1
# 82581            107  高雄市左營區        18歲      18歲          1
# 87313            107  高雄市前鎮區        18歲      18歲          1
# 88665            107  高雄市小港區        18歲      18歲          1
# ...

# %% [markdown]
# ## 輸入分別想查詢的數據

# %%
df[(df.female_age== input("輸入女方歲數"))&(df.male_age==input("輸入男方歲數"))]
# Out:
# 輸入女方歲數18歲
# 輸入男方歲數30歲
#        statistic_yyy site_id female_age male_age marry_pair
# 121              107  新北市板橋區        18歲      30歲          0
# 797              107  新北市三重區        18歲      30歲          1
# 1473             107  新北市中和區        18歲      30歲          0
# 2149             107  新北市永和區        18歲      30歲          0
# 2825             107  新北市新莊區        18歲      30歲          0
# 3501             107  新北市新店區        18歲      30歲          1
# 4177             107  新北市樹林區        18歲      30歲          0
# 4853             107  新北市鶯歌區        18歲      30歲          0
# 5529             107  新北市三峽區        18歲      30歲          0
# 6205             107  新北市淡水區        18歲      30歲          1
# 6881             107  新北市汐止區        18歲      30歲          0
# 7557             107  新北市瑞芳區        18歲      30歲          0
# 8233             107  新北市土城區        18歲      30歲          0
# 8909             107  新北市蘆洲區        18歲      30歲          1
# ...
